# %% [markdown]
# # Installation

# %%
# !pip install wandb -qqq > /dev/null
import wandb

wandb.login()
# Out:
# wandb: Currently logged in as: 367121 (house-666). Use `wandb login --relogin` to force relogin
# True

# %%
# !rm -rf modpo

# !git clone https://github.com/ZHZisZZ/modpo.git > /dev/null
# Out:
# Cloning into 'modpo'...
# remote: Enumerating objects: 164, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 164 (delta 67), reused 154 (delta 57), pack-reused 0 (from 0)
# Receiving objects: 100% (164/164), 58.64 KiB | 3.26 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
# conda create -n modpo python=3.10
# conda activate modpo
# !pip install torch==2.1.0 --index-url https://download.pytorch.org/whl/cu118
# !pip install -r requirements.txt
# # (optional) pip install flash-attn==2.3.2 --no-build-isolation

# %%
# Colab version for CPU, else modify code above

# > /dev/null - to hide messages, but watch warning and errors
# !pip install virtualenv > /dev/null
# !virtualenv modpo > /dev/null

# !source modpo/bin/activate > /dev/null

# !pip install torch==2.1.0 --index-url https://download.pytorch.org/whl/cu118 > /dev/null

# !pip install -r modpo/requirements.txt > /dev/null

# !pip install flash-attn==2.3.2 --no-build-isolation > /dev/null

# %%
# another collab version for T4

# !pip uninstall -y torch torchaudio torchvision fsspec gcsfs datasets bigframes trl > /dev/null

# !pip install torch==2.4.1 torchaudio==2.4.1 torchvision==0.19.1 --index-url https://download.pytorch.org/whl/cu121 > /dev/null
# !pip install fsspec==2023.6.0 gcsfs>=2023.3.0 > /dev/null

# !pip install datasets==2.14.5 > /dev/null

# !pip install -r modpo/requirements.txt > /dev/null
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping datasets as it is not installed.
# WARNING: Skipping bigframes as it is not installed.
# WARNING: Skipping trl as it is not installed.

# %% [markdown]
# # Обучение авторской модели

# %%
# import os

# os.chdir("modpo")

# # modified num_processes: 8 -> 1
# # edit your number!
# !PYTHONPATH=. accelerate launch --config_file scripts/accelerate_configs/multi_gpu.yaml --num_processes=1 \
#     scripts/examples/dpo/dpo.py \
#     --sft_model_name "PKU-Alignment/alpaca-7b-reproduced" \
#     --prompt_template "BEGINNING OF CONVERSATION: USER: {raw_prompt} ASSISTANT:" \
#     --dataset_name "PKU-Alignment/PKU-SafeRLHF-10K-safer" \
#     --max_length 512 \
#     --training_args.output_dir "./output/PKU-Alignment/PKU-SafeRLHF-10K/modpo/rm/safer" \
#     --training_args.run_name "PKU-Alignment/PKU-SafeRLHF-10K/modpo/rm/safer" \
#     --training_args.per_device_train_batch_size 6 \
#     --training_args.per_device_eval_batch_size 6 \
#     --training_args.gradient_accumulation_steps 2 \
#     --training_args.learning_rate 5e-4 \
#     --peft_config.r 64 \
#     --peft_config.target_modules q_proj k_proj v_proj o_proj \
#     --peft_config.lora_alpha 1 \
#     --peft_config.lora_dropout 0

# %% [markdown]
# # Тест на маленьком датасете и низком качестве гиперпараметров

# %%
# import shutil
# import os

# cache_dir = os.path.expanduser("~/.cache/huggingface/datasets")
# shutil.rmtree(cache_dir)
# print(f"Кэш Hugging Face очищен: {cache_dir}")

# %%
# # Загрузка основного датасета
# from datasets import load_dataset

# dataset = load_dataset("PKU-Alignment/PKU-SafeRLHF-10K")

# print(dataset)

# %%
# num_examples = len(dataset["train"])
# subset_size = int(num_examples * 0.01)

# small_subset = dataset["train"].shuffle(seed=42).select(range(subset_size))

# print(small_subset)

# %%
import os

os.chdir("modpo")

# !PYTHONPATH=. accelerate launch --config_file scripts/accelerate_configs/multi_gpu.yaml --num_processes=1 \
    scripts/examples/dpo/dpo.py \
    --sft_model_name "distilgpt2" \
    --prompt_template "BEGINNING OF CONVERSATION: USER: {raw_prompt} ASSISTANT:" \
    --dataset_name "PKU-Alignment/PKU-SafeRLHF-10K-safer" \
    --max_length 128 \
    --training_args.output_dir "./output/PKU-Alignment/PKU-SafeRLHF-10K/modpo/rm/safer" \
    --training_args.run_name "PKU-Alignment/PKU-SafeRLHF-10K/modpo/rm/safer" \
    --training_args.per_device_train_batch_size 1 \
    --training_args.per_device_eval_batch_size 1 \
    --training_args.gradient_accumulation_steps 1 \
    --training_args.learning_rate 5e-4 \
    --peft_config.r 2 \
    --peft_config.lora_alpha 1 \
    --peft_config.lora_dropout 0
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# 2024-10-15 10:53:21.973618: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-15 10:53:22.003247: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-15 10:53:22.012685: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-15 10:53:23.704196: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tyro/_resolver.py:285: UserWarning: <class 'dict'> does not match any type in Union: [<class 'str'>, <class 'NoneType'>]
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tyro/_fields.py:333: UserWarning: The field base_model_name_or_path is annotated with type <class 'str'>, but the default value None has type <class 'NoneType'>. We'll try to handle this gracefully, but it may cause unexpected behavior.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tyro/_fields.py:333: UserWarning: The field revision is annotated with type <class 'str'>, but the default value None has type <class 'NoneType'>. We'll try to handle this gracefully, but it may cause unexpected behavior.
#   warnings.warn(
# loading model...
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:437: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# Downloading config.json: 100% 762/762 [00:00<00:00, 3.28MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# Downloading model.safetensors: 100% 353M/353M [00:01<00:00, 187MB/s]
# Downloading generation_config.json: 100% 124/124 [00:00<00:00, 674kB/s]
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-5): 6 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )
# LoraConfig(peft_type=<PeftType.LORA: 'LORA'>, auto_mapping=None, base_model_name_or_path=None, revision=None, task_type='CAUSAL_LM', inference_mode=False, r=2, target_modules=None, lora_alpha=1, lora_dropout=0.0, fan_in_fan_out=False, bias='none', modules_to_save=None, init_lora_weights=True, layers_to_transform=None, layers_pattern=None)
# Downloading tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 166kB/s]
# Downloading vocab.json: 100% 1.04M/1.04M [00:00<00:00, 14.3MB/s]
# Downloading merges.txt: 100% 456k/456k [00:00<00:00, 14.9MB/s]
# Downloading tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 11.3MB/s]
# mapping dataset to standard format...
# Map (num_proc=4): 100% 9000/9000 [00:01<00:00, 6657.03 examples/s]
# /usr/local/lib/python3.10/dist-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# mapping dataset to standard format...
# Map (num_proc=4): 100% 1000/1000 [00:00<00:00, 3017.99 examples/s]
# start training...
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora.py:475: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# dataset preprocessing...
# Map (num_proc=4):   0% 0/9000 [00:00<?, ? examples/s]/usr/local/lib/python3.10/dist-packages/datasets/table.py:1387: FutureWarning: promote has been superseded by promote_options='default'.
#   return cls._concat_blocks(pa_tables_to_concat_vertically, axis=0)
# /usr/local/lib/python3.10/dist-packages/datasets/table.py:1387: FutureWarning: promote has been superseded by promote_options='default'.
#   return cls._concat_blocks(pa_tables_to_concat_vertically, axis=0)
# /usr/local/lib/python3.10/dist-packages/datasets/table.py:1387: FutureWarning: promote has been superseded by promote_options='default'.
#   return cls._concat_blocks(pa_tables_to_concat_vertically, axis=0)
# /usr/local/lib/python3.10/dist-packages/datasets/table.py:1387: FutureWarning: promote has been superseded by promote_options='default'.
#   return cls._concat_blocks(pa_tables_to_concat_vertically, axis=0)
# Map (num_proc=4): 100% 9000/9000 [00:09<00:00, 957.76 examples/s]
# Filter: 100% 9000/9000 [00:02<00:00, 3523.91 examples/s]
# Map (num_proc=4):   0% 0/1000 [00:00<?, ? examples/s]/usr/local/lib/python3.10/dist-packages/datasets/table.py:1387: FutureWarning: promote has been superseded by promote_options='default'.
#   return cls._concat_blocks(pa_tables_to_concat_vertically, axis=0)
# /usr/local/lib/python3.10/dist-packages/datasets/table.py:1387: FutureWarning: promote has been superseded by promote_options='default'.
#   return cls._concat_blocks(pa_tables_to_concat_vertically, axis=0)
# /usr/local/lib/python3.10/dist-packages/datasets/table.py:1387: FutureWarning: promote has been superseded by promote_options='default'.
#   return cls._concat_blocks(pa_tables_to_concat_vertically, axis=0)
# /usr/local/lib/python3.10/dist-packages/datasets/table.py:1387: FutureWarning: promote has been superseded by promote_options='default'.
#   return cls._concat_blocks(pa_tables_to_concat_vertically, axis=0)
# Map (num_proc=4): 100% 1000/1000 [00:01<00:00, 730.83 examples/s]
# Filter: 100% 1000/1000 [00:00<00:00, 3666.56 examples/s]
# train_dataset_retain: 0.6082222222222222
# eval_dataset_retain: 0.623
# wandb: Currently logged in as: 367121 (house-666). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.18.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in /content/modpo/wandb/run-20241015_105347-c729vaj9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run PKU-Alignment/PKU-SafeRLHF-10K/modpo/rm/safer
# wandb: ⭐️ View project at https://wandb.ai/house-666/huggingface
# wandb: 🚀 View run at https://wandb.ai/house-666/huggingface/runs/c729vaj9
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:437: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# trainable params: 36,864 || all params: 81,949,440 || trainable%: 0.04498383393467972
#   0% 0/16422 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# [rank0]:[W1015 10:53:49.656577244 reducer.cpp:1400] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# {'loss': 0.6927, 'learning_rate': 0.0004999996376378229, 'rewards/margins': 0.000891790259629488, 'rewards/chosen': -0.000912246759980917, 'rewards/rejected': -0.0018040367867797613, 'logps/margins': 12.377039909362793, 'logps/chosen': -135.9128875732422, 'logps/rejected': -148.2899169921875, 'accuracy': 0.4000000059604645, 'epoch': 0.0}
# {'loss': 0.6941, 'learning_rate': 0.0004999983658719408, 'rewards/margins': -0.001812953851185739, 'rewards/chosen': 0.0018663216615095735, 'rewards/rejected': 0.003679275047034025, 'logps/margins': 10.398104667663574, 'logps/chosen': -170.7759552001953, 'logps/rejected': -181.17405700683594, 'accuracy': 0.30000001192092896, 'epoch': 0.0}
# {'loss': 0.6905, 'learning_rate': 0.000499996179171617, 'rewards/margins': 0.005467567592859268, 'rewards/chosen': 0.001046142540872097, 'rewards/rejected': -0.004421425051987171, 'logps/margins': -2.3845863342285156, 'logps/chosen': -159.5156707763672, 'logps/rejected': -157.13107299804688, 'accuracy': 0.30000001192092896, 'epoch': 0.01}
# {'loss': 0.7, 'learning_rate': 0.0004999930775448544, 'rewards/margins': -0.013617840595543385, 'rewards/chosen': -0.015320549719035625, 'rewards/rejected': -0.0017027093563228846, 'logps/margins': -18.02101707458496, 'logps/chosen': -175.69253540039062, 'logps/rejected': -157.67149353027344, 'accuracy': 0.20000000298023224, 'epoch': 0.01}
# {'loss': 0.6946, 'learning_rate': 0.0004999890610030042, 'rewards/margins': -0.002933921292424202, 'rewards/chosen': -0.007734375540167093, 'rewards/rejected': -0.004800452850759029, 'logps/margins': 47.262611389160156, 'logps/chosen': -157.31954956054688, 'logps/rejected': -204.58218383789062, 'accuracy': 0.6000000238418579, 'epoch': 0.01}
# {'loss': 0.6893, 'learning_rate': 0.0004999841295607658, 'rewards/margins': 0.007762985769659281, 'rewards/chosen': 0.0024005891755223274, 'rewards/rejected': -0.005362396128475666, 'logps/margins': 31.700515747070312, 'logps/chosen': -141.6110382080078, 'logps/rejected': -173.31155395507812, 'accuracy': 0.8999999761581421, 'epoch': 0.01}
# {'loss': 0.6962, 'learning_rate': 0.0004999782832361873, 'rewards/margins': -0.0060679251328110695, 'rewards/chosen': -0.009373932145535946, 'rewards/rejected': -0.0033060074783861637, 'logps/margins': -7.388040065765381, 'logps/chosen': -162.79318237304688, 'logps/rejected': -155.40513610839844, 'accuracy': 0.30000001192092896, 'epoch': 0.01}
# {'loss': 0.6919, 'learning_rate': 0.0004999715220506647, 'rewards/margins': 0.0025125890970230103, 'rewards/chosen': -0.0035424046218395233, 'rewards/rejected': -0.006054992787539959, 'logps/margins': 27.468738555908203, 'logps/chosen': -172.26861572265625, 'logps/rejected': -199.7373504638672, 'accuracy': 0.5, 'epoch': 0.01}
# {'loss': 0.6882, 'learning_rate': 0.0004999638460289424, 'rewards/margins': 0.010096969082951546, 'rewards/chosen': -0.0028914641588926315, 'rewards/rejected': -0.012988433241844177, 'logps/margins': 33.577354431152344, 'logps/chosen': -186.03924560546875, 'logps/rejected': -219.61660766601562, 'accuracy': 0.699999988079071, 'epoch': 0.02}
# {'loss': 0.6895, 'learning_rate': 0.0004999552551991129, 'rewards/margins': 0.007367210928350687, 'rewards/chosen': 0.010875320062041283, 'rewards/rejected': 0.0035081100650131702, 'logps/margins': -14.975929260253906, 'logps/chosen': -124.7342758178711, 'logps/rejected': -109.75834655761719, 'accuracy': 0.800000011920929, 'epoch': 0.02}
# {'loss': 0.6905, 'learning_rate': 0.0004999457495926164, 'rewards/margins': 0.005394020117819309, 'rewards/chosen': 0.004351464100182056, 'rewards/rejected': -0.0010425568325445056, 'logps/margins': 28.307994842529297, 'logps/chosen': -129.10525512695312, 'logps/rejected': -157.41323852539062, 'accuracy': 0.6000000238418579, 'epoch': 0.02}
# {'loss': 0.691, 'learning_rate': 0.0004999353292442412, 'rewards/margins': 0.004304771311581135, 'rewards/chosen': -0.004167099017649889, 'rewards/rejected': -0.008471870794892311, 'logps/margins': 27.794803619384766, 'logps/chosen': -122.0660171508789, 'logps/rejected': -149.86083984375, 'accuracy': 0.5, 'epoch': 0.02}
# {'loss': 0.6948, 'learning_rate': 0.0004999239941921235, 'rewards/margins': -0.0032133865170180798, 'rewards/chosen': -0.007330246269702911, 'rewards/rejected': -0.004116859287023544, 'logps/margins': -2.180131435394287, 'logps/chosen': -135.87123107910156, 'logps/rejected': -133.6910858154297, 'accuracy': 0.4000000059604645, 'epoch': 0.02}
# {'loss': 0.6927, 'learning_rate': 0.0004999117444777466, 'rewards/margins': 0.001183433341793716, 'rewards/chosen': 4.302961679059081e-05, 'rewards/rejected': -0.0011404033284634352, 'logps/margins': -19.732437133789062, 'logps/chosen': -172.10533142089844, 'logps/rejected': -152.37290954589844, 'accuracy': 0.5, 'epoch': 0.03}
# {'loss': 0.6927, 'learning_rate': 0.0004998985801459417, 'rewards/margins': 0.0010791399981826544, 'rewards/chosen': 0.001148872310295701, 'rewards/rejected': 6.973240670049563e-05, 'logps/margins': 49.168094635009766, 'logps/chosen': -144.9939422607422, 'logps/rejected': -194.16204833984375, 'accuracy': 0.4000000059604645, 'epoch': 0.03}
# {'loss': 0.6922, 'learning_rate': 0.0004998845012448872, 'rewards/margins': 0.0020162872970104218, 'rewards/chosen': 0.0007074832683429122, 'rewards/rejected': -0.0013088034465909004, 'logps/margins': -11.422456741333008, 'logps/chosen': -161.45323181152344, 'logps/rejected': -150.03079223632812, 'accuracy': 0.5, 'epoch': 0.03}
# {'loss': 0.6953, 'learning_rate': 0.0004998695078261083, 'rewards/margins': -0.004271087236702442, 'rewards/chosen': 0.005235481075942516, 'rewards/rejected': 0.009506569243967533, 'logps/margins': -17.5606746673584, 'logps/chosen': -145.72927856445312, 'logps/rejected': -128.16860961914062, 'accuracy': 0.5, 'epoch': 0.03}
# {'loss': 0.6934, 'learning_rate': 0.0004998535999444774, 'rewards/margins': -0.0004882434441242367, 'rewards/chosen': -0.0032506748102605343, 'rewards/rejected': -0.002762432210147381, 'logps/margins': 7.020216464996338, 'logps/chosen': -111.6963119506836, 'logps/rejected': -118.7165298461914, 'accuracy': 0.5, 'epoch': 0.03}
# {'loss': 0.6931, 'learning_rate': 0.0004998367776582137, 'rewards/margins': 0.00017379768542014062, 'rewards/chosen': 0.000861320469994098, 'rewards/rejected': 0.000687522697262466, 'logps/margins': -14.320783615112305, 'logps/chosen': -146.84698486328125, 'logps/rejected': -132.5261993408203, 'accuracy': 0.6000000238418579, 'epoch': 0.03}
# {'loss': 0.6973, 'learning_rate': 0.0004998190410288826, 'rewards/margins': -0.008254623040556908, 'rewards/chosen': -0.0016434859717264771, 'rewards/rejected': 0.006611138582229614, 'logps/margins': -23.956336975097656, 'logps/chosen': -194.2691650390625, 'logps/rejected': -170.3128204345703, 'accuracy': 0.4000000059604645, 'epoch': 0.04}
# {'loss': 0.6959, 'learning_rate': 0.000499800390121396, 'rewards/margins': -0.005007132887840271, 'rewards/chosen': -0.010100098326802254, 'rewards/rejected': -0.005092964507639408, 'logps/margins': -7.924494743347168, 'logps/chosen': -160.3243865966797, 'logps/rejected': -152.39988708496094, 'accuracy': 0.4000000059604645, 'epoch': 0.04}
# {'loss': 0.6962, 'learning_rate': 0.0004997808250040118, 'rewards/margins': -0.006093407049775124, 'rewards/chosen': -0.0021521758753806353, 'rewards/rejected': 0.003941230941563845, 'logps/margins': -13.571342468261719, 'logps/chosen': -163.12010192871094, 'logps/rejected': -149.54876708984375, 'accuracy': 0.30000001192092896, 'epoch': 0.04}
# {'loss': 0.6924, 'learning_rate': 0.0004997603457483337, 'rewards/margins': 0.0017013937467709184, 'rewards/chosen': 0.006098938174545765, 'rewards/rejected': 0.004397544544190168, 'logps/margins': 5.053441047668457, 'logps/chosen': -149.40501403808594, 'logps/rejected': -154.4584503173828, 'accuracy': 0.4000000059604645, 'epoch': 0.04}
# {'loss': 0.6949, 'learning_rate': 0.0004997389524293108, 'rewards/margins': -0.00341842626221478, 'rewards/chosen': 0.0012068559881299734, 'rewards/rejected': 0.004625282250344753, 'logps/margins': -55.21356201171875, 'logps/chosen': -145.03860473632812, 'logps/rejected': -89.8250503540039, 'accuracy': 0.6000000238418579, 'epoch': 0.04}
# {'loss': 0.6876, 'learning_rate': 0.0004997166451252376, 'rewards/margins': 0.011241226457059383, 'rewards/chosen': 0.0026745605282485485, 'rewards/rejected': -0.008566666394472122, 'logps/margins': 33.26029586791992, 'logps/chosen': -135.1729736328125, 'logps/rejected': -168.43328857421875, 'accuracy': 0.6000000238418579, 'epoch': 0.05}
# {'loss': 0.6962, 'learning_rate': 0.0004996934239177535, 'rewards/margins': -0.00569229107350111, 'rewards/chosen': 0.005505295004695654, 'rewards/rejected': 0.011197586543858051, 'logps/margins': -6.685066223144531, 'logps/chosen': -176.94570922851562, 'logps/rejected': -170.26063537597656, 'accuracy': 0.4000000059604645, 'epoch': 0.05}
# {'loss': 0.6894, 'learning_rate': 0.0004996692888918425, 'rewards/margins': 0.007768402807414532, 'rewards/chosen': 0.008855095133185387, 'rewards/rejected': 0.001086693024262786, 'logps/margins': 34.909637451171875, 'logps/chosen': -124.71659851074219, 'logps/rejected': -159.62623596191406, 'accuracy': 0.5, 'epoch': 0.05}
# {'loss': 0.6904, 'learning_rate': 0.0004996442401358332, 'rewards/margins': 0.0057806759141385555, 'rewards/chosen': 0.018683016300201416, 'rewards/rejected': 0.01290233712643385, 'logps/margins': -10.299349784851074, 'logps/chosen': -134.62429809570312, 'logps/rejected': -124.32496643066406, 'accuracy': 0.5, 'epoch': 0.05}
# {'loss': 0.6853, 'learning_rate': 0.000499618277741398, 'rewards/margins': 0.016159765422344208, 'rewards/chosen': 0.02556038275361061, 'rewards/rejected': 0.009400615468621254, 'logps/margins': -59.0034065246582, 'logps/chosen': -192.73159790039062, 'logps/rejected': -133.7281951904297, 'accuracy': 0.699999988079071, 'epoch': 0.05}
# {'loss': 0.6972, 'learning_rate': 0.0004995914018035531, 'rewards/margins': -0.007853545248508453, 'rewards/chosen': 0.020868567749857903, 'rewards/rejected': 0.028722116723656654, 'logps/margins': -6.207841396331787, 'logps/chosen': -159.4741973876953, 'logps/rejected': -153.26634216308594, 'accuracy': 0.4000000059604645, 'epoch': 0.05}
# {'loss': 0.6803, 'learning_rate': 0.0004995636124206581, 'rewards/margins': 0.026068340986967087, 'rewards/chosen': 0.03680393844842911, 'rewards/rejected': 0.010735588148236275, 'logps/margins': -44.704734802246094, 'logps/chosen': -158.01007080078125, 'logps/rejected': -113.3053207397461, 'accuracy': 0.800000011920929, 'epoch': 0.06}
# {'loss': 0.6854, 'learning_rate': 0.0004995378210645226, 'rewards/margins': 0.016255836933851242, 'rewards/chosen': 0.033705905079841614, 'rewards/rejected': 0.01745006814599037, 'logps/margins': -4.82201623916626, 'logps/chosen': -167.6495819091797, 'logps/rejected': -162.82757568359375, 'accuracy': 0.5, 'epoch': 0.06}
# {'loss': 0.6909, 'learning_rate': 0.0004995082964189853, 'rewards/margins': 0.00629096943885088, 'rewards/chosen': 0.07902596145868301, 'rewards/rejected': 0.07273498177528381, 'logps/margins': 16.51237678527832, 'logps/chosen': -150.33651733398438, 'logps/rejected': -166.84890747070312, 'accuracy': 0.5, 'epoch': 0.06}
# {'loss': 0.6877, 'learning_rate': 0.0004994778586325437, 'rewards/margins': 0.01313346903771162, 'rewards/chosen': 0.05221496894955635, 'rewards/rejected': 0.039081498980522156, 'logps/margins': 0.39805299043655396, 'logps/chosen': -181.16140747070312, 'logps/rejected': -181.5594482421875, 'accuracy': 0.5, 'epoch': 0.06}
# {'loss': 0.6929, 'learning_rate': 0.0004994465078165929, 'rewards/margins': 0.001480711973272264, 'rewards/chosen': 0.057861022651195526, 'rewards/rejected': 0.05638031288981438, 'logps/margins': -21.72574806213379, 'logps/chosen': -153.79383850097656, 'logps/rejected': -132.0680694580078, 'accuracy': 0.5, 'epoch': 0.06}
# {'loss': 0.6883, 'learning_rate': 0.0004994142440858694, 'rewards/margins': 0.010383913293480873, 'rewards/chosen': 0.03899376094341278, 'rewards/rejected': 0.028609847649931908, 'logps/margins': 17.09029769897461, 'logps/chosen': -138.27401733398438, 'logps/rejected': -155.36431884765625, 'accuracy': 0.5, 'epoch': 0.07}
# {'loss': 0.6883, 'learning_rate': 0.0004993810675584506, 'rewards/margins': 0.013540878891944885, 'rewards/chosen': 0.07060036063194275, 'rewards/rejected': 0.057059478014707565, 'logps/margins': -29.258544921875, 'logps/chosen': -169.1258544921875, 'logps/rejected': -139.86732482910156, 'accuracy': 0.5, 'epoch': 0.07}
# {'loss': 0.6908, 'learning_rate': 0.0004993469783557549, 'rewards/margins': 0.0058619859628379345, 'rewards/chosen': 0.027860427275300026, 'rewards/rejected': 0.021998444572091103, 'logps/margins': -22.00981903076172, 'logps/chosen': -156.2672119140625, 'logps/rejected': -134.2573699951172, 'accuracy': 0.6000000238418579, 'epoch': 0.07}
# {'loss': 0.6777, 'learning_rate': 0.0004993119766025406, 'rewards/margins': 0.03272159770131111, 'rewards/chosen': 0.09257838875055313, 'rewards/rejected': 0.059856779873371124, 'logps/margins': 6.466639041900635, 'logps/chosen': -121.18537902832031, 'logps/rejected': -127.6520004272461, 'accuracy': 0.800000011920929, 'epoch': 0.07}
# {'loss': 0.7033, 'learning_rate': 0.0004992760624269059, 'rewards/margins': -0.018952200189232826, 'rewards/chosen': 0.037981681525707245, 'rewards/rejected': 0.05693387985229492, 'logps/margins': 48.48894500732422, 'logps/chosen': -124.30946350097656, 'logps/rejected': -172.7984161376953, 'accuracy': 0.5, 'epoch': 0.07}
# {'loss': 0.6943, 'learning_rate': 0.0004992392359602877, 'rewards/margins': -0.0012982562184333801, 'rewards/chosen': 0.06234417110681534, 'rewards/rejected': 0.06364242732524872, 'logps/margins': 18.676355361938477, 'logps/chosen': -166.2978515625, 'logps/rejected': -184.97421264648438, 'accuracy': 0.5, 'epoch': 0.07}
# {'loss': 0.6988, 'learning_rate': 0.0004992014973374626, 'rewards/margins': -0.009006386622786522, 'rewards/chosen': -0.010923539288341999, 'rewards/rejected': -0.0019171524327248335, 'logps/margins': 39.641395568847656, 'logps/chosen': -168.27735900878906, 'logps/rejected': -207.9187469482422, 'accuracy': 0.30000001192092896, 'epoch': 0.08}
# {'loss': 0.6903, 'learning_rate': 0.0004991628466965446, 'rewards/margins': 0.0076902792789042, 'rewards/chosen': 0.07309814542531967, 'rewards/rejected': 0.06540787220001221, 'logps/margins': -21.07140350341797, 'logps/chosen': -230.510009765625, 'logps/rejected': -209.43862915039062, 'accuracy': 0.6000000238418579, 'epoch': 0.08}
# {'loss': 0.6462, 'learning_rate': 0.0004991232841789861, 'rewards/margins': 0.0977756679058075, 'rewards/chosen': 0.09533607959747314, 'rewards/rejected': -0.0024395943619310856, 'logps/margins': 9.627828598022461, 'logps/chosen': -177.1471405029297, 'logps/rejected': -186.7749786376953, 'accuracy': 0.8999999761581421, 'epoch': 0.08}
# {'loss': 0.7087, 'learning_rate': 0.0004990828099295763, 'rewards/margins': -0.029378969222307205, 'rewards/chosen': 0.06693717837333679, 'rewards/rejected': 0.0963161438703537, 'logps/margins': 2.8475582599639893, 'logps/chosen': -136.69081115722656, 'logps/rejected': -139.53836059570312, 'accuracy': 0.20000000298023224, 'epoch': 0.08}
# {'loss': 0.6786, 'learning_rate': 0.0004990414240964413, 'rewards/margins': 0.030537759885191917, 'rewards/chosen': 0.1123884916305542, 'rewards/rejected': 0.08185074478387833, 'logps/margins': 1.0610930919647217, 'logps/chosen': -114.62162780761719, 'logps/rejected': -115.6827163696289, 'accuracy': 0.699999988079071, 'epoch': 0.08}
# {'loss': 0.684, 'learning_rate': 0.0004989991268310436, 'rewards/margins': 0.019183482974767685, 'rewards/chosen': 0.05005618929862976, 'rewards/rejected': 0.030872706323862076, 'logps/margins': 22.006240844726562, 'logps/chosen': -87.49273681640625, 'logps/rejected': -109.49897766113281, 'accuracy': 0.699999988079071, 'epoch': 0.09}
# {'loss': 0.6738, 'learning_rate': 0.0004989559182881809, 'rewards/margins': 0.04508713632822037, 'rewards/chosen': 0.043696630746126175, 'rewards/rejected': -0.001390495104715228, 'logps/margins': -3.5304627418518066, 'logps/chosen': -182.7079620361328, 'logps/rejected': -179.17750549316406, 'accuracy': 0.6000000238418579, 'epoch': 0.09}
# {'loss': 0.6752, 'learning_rate': 0.0004989117986259862, 'rewards/margins': 0.03859443962574005, 'rewards/chosen': 0.14103813469409943, 'rewards/rejected': 0.10244369506835938, 'logps/margins': 17.925613403320312, 'logps/chosen': -133.02796936035156, 'logps/rejected': -150.95358276367188, 'accuracy': 0.699999988079071, 'epoch': 0.09}
# {'loss': 0.7128, 'learning_rate': 0.000498866768005927, 'rewards/margins': -0.03045898675918579, 'rewards/chosen': 0.08257857710123062, 'rewards/rejected': 0.11303756386041641, 'logps/margins': -13.215875625610352, 'logps/chosen': -206.1473846435547, 'logps/rejected': -192.93154907226562, 'accuracy': 0.4000000059604645, 'epoch': 0.09}
# {'loss': 0.6771, 'learning_rate': 0.0004988208265928047, 'rewards/margins': 0.03611614555120468, 'rewards/chosen': 0.10465233027935028, 'rewards/rejected': 0.0685361847281456, 'logps/margins': -5.7736101150512695, 'logps/chosen': -156.85574340820312, 'logps/rejected': -151.08212280273438, 'accuracy': 0.4000000059604645, 'epoch': 0.09}
# {'loss': 0.6821, 'learning_rate': 0.0004987739745547538, 'rewards/margins': 0.0231003575026989, 'rewards/chosen': 0.08746276795864105, 'rewards/rejected': 0.06436241418123245, 'logps/margins': -23.247333526611328, 'logps/chosen': -171.4271240234375, 'logps/rejected': -148.17979431152344, 'accuracy': 0.699999988079071, 'epoch': 0.09}
# {'loss': 0.6479, 'learning_rate': 0.0004987262120632417, 'rewards/margins': 0.09498576074838638, 'rewards/chosen': 0.08477596193552017, 'rewards/rejected': -0.010209793224930763, 'logps/margins': -6.285128593444824, 'logps/chosen': -166.26107788085938, 'logps/rejected': -159.9759521484375, 'accuracy': 0.800000011920929, 'epoch': 0.1}
# {'loss': 0.6376, 'learning_rate': 0.0004986775392930676, 'rewards/margins': 0.1182166188955307, 'rewards/chosen': 0.15227410197257996, 'rewards/rejected': 0.03405747562646866, 'logps/margins': -13.8799409866333, 'logps/chosen': -143.64947509765625, 'logps/rejected': -129.76954650878906, 'accuracy': 0.800000011920929, 'epoch': 0.1}
# {'loss': 0.7059, 'learning_rate': 0.0004986279564223623, 'rewards/margins': -0.01972583308815956, 'rewards/chosen': 0.12240730226039886, 'rewards/rejected': 0.14213314652442932, 'logps/margins': -16.345760345458984, 'logps/chosen': -123.02091217041016, 'logps/rejected': -106.6751480102539, 'accuracy': 0.4000000059604645, 'epoch': 0.1}
# {'loss': 0.6818, 'learning_rate': 0.0004985774636325873, 'rewards/margins': 0.036025069653987885, 'rewards/chosen': 0.20100155472755432, 'rewards/rejected': 0.16497652232646942, 'logps/margins': 21.794330596923828, 'logps/chosen': -121.10176849365234, 'logps/rejected': -142.89608764648438, 'accuracy': 0.6000000238418579, 'epoch': 0.1}
# {'loss': 0.6478, 'learning_rate': 0.0004985260611085344, 'rewards/margins': 0.10270603001117706, 'rewards/chosen': 0.2676694393157959, 'rewards/rejected': 0.16496342420578003, 'logps/margins': 19.02953338623047, 'logps/chosen': -122.22900390625, 'logps/rejected': -141.25852966308594, 'accuracy': 0.6000000238418579, 'epoch': 0.1}
# {'loss': 0.6617, 'learning_rate': 0.0004984737490383241, 'rewards/margins': 0.07554489374160767, 'rewards/chosen': 0.23660250008106232, 'rewards/rejected': 0.16105757653713226, 'logps/margins': -8.229390144348145, 'logps/chosen': -154.9073486328125, 'logps/rejected': -146.67796325683594, 'accuracy': 0.6000000238418579, 'epoch': 0.11}
# {'loss': 0.6844, 'learning_rate': 0.0004984205276134065, 'rewards/margins': 0.023437535390257835, 'rewards/chosen': 0.14407691359519958, 'rewards/rejected': 0.1206393837928772, 'logps/margins': -43.4774055480957, 'logps/chosen': -185.1190643310547, 'logps/rejected': -141.6416778564453, 'accuracy': 0.6000000238418579, 'epoch': 0.11}
# {'loss': 0.6683, 'learning_rate': 0.0004983663970285592, 'rewards/margins': 0.05659347027540207, 'rewards/chosen': 0.26108866930007935, 'rewards/rejected': 0.20449522137641907, 'logps/margins': 22.541614532470703, 'logps/chosen': -139.56918334960938, 'logps/rejected': -162.11082458496094, 'accuracy': 0.6000000238418579, 'epoch': 0.11}
# {'loss': 0.7329, 'learning_rate': 0.0004983113574818874, 'rewards/margins': -0.0656547099351883, 'rewards/chosen': 0.19494807720184326, 'rewards/rejected': 0.260602742433548, 'logps/margins': 34.87822723388672, 'logps/chosen': -113.00102233886719, 'logps/rejected': -147.87924194335938, 'accuracy': 0.30000001192092896, 'epoch': 0.11}
# {'loss': 0.6353, 'learning_rate': 0.0004982554091748225, 'rewards/margins': 0.13744887709617615, 'rewards/chosen': 0.14821329712867737, 'rewards/rejected': 0.010764405131340027, 'logps/margins': 3.9018561840057373, 'logps/chosen': -135.42556762695312, 'logps/rejected': -139.32742309570312, 'accuracy': 0.699999988079071, 'epoch': 0.11}
# {'loss': 0.5764, 'learning_rate': 0.000498198552312122, 'rewards/margins': 0.2779068350791931, 'rewards/chosen': 0.2622568607330322, 'rewards/rejected': -0.015649979934096336, 'logps/margins': 4.253196716308594, 'logps/chosen': -152.30569458007812, 'logps/rejected': -156.5588836669922, 'accuracy': 0.699999988079071, 'epoch': 0.12}
#   4% 635/16422 [00:29<11:06, 23.68it/s]wandb: 429 encountered (Filestream rate limit exceeded, retrying in 2.1 seconds.), retrying request
# {'loss': 0.6947, 'learning_rate': 0.0004981407871018685, 'rewards/margins': 0.020259732380509377, 'rewards/chosen': 0.34582215547561646, 'rewards/rejected': 0.32556238770484924, 'logps/margins': -54.95845413208008, 'logps/chosen': -174.44979858398438, 'logps/rejected': -119.4913558959961, 'accuracy': 0.4000000059604645, 'epoch': 0.12}
# {'loss': 0.7071, 'learning_rate': 0.000498082113755469, 'rewards/margins': -0.008903047069907188, 'rewards/chosen': 0.06252594292163849, 'rewards/rejected': 0.07142899930477142, 'logps/margins': -21.497928619384766, 'logps/chosen': -176.6996612548828, 'logps/rejected': -155.20169067382812, 'accuracy': 0.5, 'epoch': 0.12}
# {'loss': 0.6425, 'learning_rate': 0.0004980225324876539, 'rewards/margins': 0.13924364745616913, 'rewards/chosen': 0.34258514642715454, 'rewards/rejected': 0.20334145426750183, 'logps/margins': 15.655322074890137, 'logps/chosen': -151.2354736328125, 'logps/rejected': -166.89077758789062, 'accuracy': 0.6000000238418579, 'epoch': 0.12}
# {'loss': 0.7288, 'learning_rate': 0.0004979620435164764, 'rewards/margins': -0.05517194792628288, 'rewards/chosen': 0.06719239056110382, 'rewards/rejected': 0.12236432731151581, 'logps/margins': 27.3709716796875, 'logps/chosen': -145.86756896972656, 'logps/rejected': -173.23855590820312, 'accuracy': 0.5, 'epoch': 0.12}
# {'loss': 0.695, 'learning_rate': 0.0004979006470633116, 'rewards/margins': 0.02235553227365017, 'rewards/chosen': 0.254691481590271, 'rewards/rejected': 0.23233595490455627, 'logps/margins': 0.372536838054657, 'logps/chosen': -124.8851318359375, 'logps/rejected': -125.2576904296875, 'accuracy': 0.699999988079071, 'epoch': 0.12}
# {'loss': 0.6623, 'learning_rate': 0.0004978383433528563, 'rewards/margins': 0.09065958112478256, 'rewards/chosen': 0.14503197371959686, 'rewards/rejected': 0.054372407495975494, 'logps/margins': 40.238441467285156, 'logps/chosen': -107.27751159667969, 'logps/rejected': -147.51596069335938, 'accuracy': 0.5, 'epoch': 0.13}
# {'loss': 0.7266, 'learning_rate': 0.0004977751326131267, 'rewards/margins': -0.03541180491447449, 'rewards/chosen': 0.13146255910396576, 'rewards/rejected': 0.16687437891960144, 'logps/margins': 6.00341272354126, 'logps/chosen': -138.65977478027344, 'logps/rejected': -144.66319274902344, 'accuracy': 0.4000000059604645, 'epoch': 0.13}
# {'loss': 0.6981, 'learning_rate': 0.0004977110150754596, 'rewards/margins': 0.009934797883033752, 'rewards/chosen': 0.2195301502943039, 'rewards/rejected': 0.20959535241127014, 'logps/margins': 17.691617965698242, 'logps/chosen': -119.0099105834961, 'logps/rejected': -136.70150756835938, 'accuracy': 0.5, 'epoch': 0.13}
# {'loss': 0.7373, 'learning_rate': 0.0004976459909745095, 'rewards/margins': -0.05283886939287186, 'rewards/chosen': 0.12517410516738892, 'rewards/rejected': 0.17801295220851898, 'logps/margins': -6.5735883712768555, 'logps/chosen': -166.11032104492188, 'logps/rejected': -159.5367431640625, 'accuracy': 0.5, 'epoch': 0.13}
# {'loss': 0.6701, 'learning_rate': 0.0004975800605482492, 'rewards/margins': 0.07133401930332184, 'rewards/chosen': 0.3312682807445526, 'rewards/rejected': 0.25993427634239197, 'logps/margins': 44.32795333862305, 'logps/chosen': -136.0716552734375, 'logps/rejected': -180.3996124267578, 'accuracy': 0.6000000238418579, 'epoch': 0.13}
# {'loss': 0.5548, 'learning_rate': 0.0004975132240379684, 'rewards/margins': 0.3106015920639038, 'rewards/chosen': 0.18258246779441833, 'rewards/rejected': -0.12801912426948547, 'logps/margins': -1.9111721515655518, 'logps/chosen': -135.3291015625, 'logps/rejected': -133.41793823242188, 'accuracy': 1.0, 'epoch': 0.14}
# {'loss': 0.6945, 'learning_rate': 0.0004974454816882727, 'rewards/margins': 0.049819935113191605, 'rewards/chosen': 0.17879708111286163, 'rewards/rejected': 0.12897714972496033, 'logps/margins': 22.81520652770996, 'logps/chosen': -136.19285583496094, 'logps/rejected': -159.00807189941406, 'accuracy': 0.4000000059604645, 'epoch': 0.14}
# {'loss': 0.5435, 'learning_rate': 0.0004973768337470832, 'rewards/margins': 0.37462884187698364, 'rewards/chosen': 0.4030309319496155, 'rewards/rejected': 0.028402060270309448, 'logps/margins': -14.365602493286133, 'logps/chosen': -136.580322265625, 'logps/rejected': -122.2147216796875, 'accuracy': 0.8999999761581421, 'epoch': 0.14}
# {'loss': 0.7106, 'learning_rate': 0.0004973072804656348, 'rewards/margins': -0.0018997043371200562, 'rewards/chosen': 0.13827787339687347, 'rewards/rejected': 0.14017759263515472, 'logps/margins': -19.853473663330078, 'logps/chosen': -103.19477844238281, 'logps/rejected': -83.34129333496094, 'accuracy': 0.6000000238418579, 'epoch': 0.14}
# {'loss': 0.7259, 'learning_rate': 0.000497236822098476, 'rewards/margins': -0.0019457160960882902, 'rewards/chosen': 0.05646160989999771, 'rewards/rejected': 0.05840732902288437, 'logps/margins': -21.96387481689453, 'logps/chosen': -190.9145050048828, 'logps/rejected': -168.9506378173828, 'accuracy': 0.5, 'epoch': 0.14}
# {'loss': 0.5738, 'learning_rate': 0.0004971654589034676, 'rewards/margins': 0.3101380467414856, 'rewards/chosen': 0.02235053852200508, 'rewards/rejected': -0.28778746724128723, 'logps/margins': 43.220069885253906, 'logps/chosen': -161.8741455078125, 'logps/rejected': -205.09423828125, 'accuracy': 0.5, 'epoch': 0.14}
# {'loss': 0.6494, 'learning_rate': 0.0004970931911417818, 'rewards/margins': 0.13917897641658783, 'rewards/chosen': 0.023683037608861923, 'rewards/rejected': -0.1154959574341774, 'logps/margins': 35.80234909057617, 'logps/chosen': -138.23907470703125, 'logps/rejected': -174.0414276123047, 'accuracy': 0.6000000238418579, 'epoch': 0.15}
# {'loss': 0.6102, 'learning_rate': 0.0004970200190779015, 'rewards/margins': 0.2236212193965912, 'rewards/chosen': 0.10687456279993057, 'rewards/rejected': -0.116746686398983, 'logps/margins': -67.08207702636719, 'logps/chosen': -207.4810028076172, 'logps/rejected': -140.39892578125, 'accuracy': 0.6000000238418579, 'epoch': 0.15}
# {'loss': 0.7993, 'learning_rate': 0.0004969459429796191, 'rewards/margins': -0.1334771066904068, 'rewards/chosen': 0.05264854431152344, 'rewards/rejected': 0.18612565100193024, 'logps/margins': -27.399555206298828, 'logps/chosen': -153.91506958007812, 'logps/rejected': -126.51551818847656, 'accuracy': 0.30000001192092896, 'epoch': 0.15}
# {'loss': 0.6475, 'learning_rate': 0.0004968709631180354, 'rewards/margins': 0.11751687526702881, 'rewards/chosen': -0.23265640437602997, 'rewards/rejected': -0.35017329454421997, 'logps/margins': 8.243825912475586, 'logps/chosen': -187.63644409179688, 'logps/rejected': -195.88027954101562, 'accuracy': 0.6000000238418579, 'epoch': 0.15}
# {'loss': 0.6958, 'learning_rate': 0.0004967950797675586, 'rewards/margins': 0.007226449437439442, 'rewards/chosen': 0.027730707079172134, 'rewards/rejected': 0.020504264160990715, 'logps/margins': -10.2016019821167, 'logps/chosen': -195.71182250976562, 'logps/rejected': -185.51022338867188, 'accuracy': 0.6000000238418579, 'epoch': 0.15}
# {'loss': 0.6984, 'learning_rate': 0.0004967182932059042, 'rewards/margins': 0.0269208662211895, 'rewards/chosen': -0.022629719227552414, 'rewards/rejected': -0.04955058544874191, 'logps/margins': -36.78656768798828, 'logps/chosen': -192.0727996826172, 'logps/rejected': -155.28622436523438, 'accuracy': 0.5, 'epoch': 0.16}
# {'loss': 0.7023, 'learning_rate': 0.0004966406037140921, 'rewards/margins': 0.011290696449577808, 'rewards/chosen': -0.025190245360136032, 'rewards/rejected': -0.036480940878391266, 'logps/margins': -2.624889373779297, 'logps/chosen': -150.00099182128906, 'logps/rejected': -147.37611389160156, 'accuracy': 0.4000000059604645, 'epoch': 0.16}
# {'loss': 0.6824, 'learning_rate': 0.0004965620115764477, 'rewards/margins': 0.055912040174007416, 'rewards/chosen': -0.00078629853669554, 'rewards/rejected': -0.05669834464788437, 'logps/margins': 3.541686534881592, 'logps/chosen': -141.16233825683594, 'logps/rejected': -144.7040252685547, 'accuracy': 0.699999988079071, 'epoch': 0.16}
# {'loss': 0.6342, 'learning_rate': 0.0004964825170805994, 'rewards/margins': 0.14870262145996094, 'rewards/chosen': 0.23800623416900635, 'rewards/rejected': 0.08930359780788422, 'logps/margins': -7.436495780944824, 'logps/chosen': -168.61276245117188, 'logps/rejected': -161.17628479003906, 'accuracy': 0.699999988079071, 'epoch': 0.16}
# {'loss': 0.7059, 'learning_rate': 0.0004964021205174781, 'rewards/margins': 0.028778165578842163, 'rewards/chosen': 0.06378152221441269, 'rewards/rejected': 0.03500334918498993, 'logps/margins': 10.00304126739502, 'logps/chosen': -176.9657745361328, 'logps/rejected': -186.9688262939453, 'accuracy': 0.5, 'epoch': 0.16}
# {'loss': 0.5831, 'learning_rate': 0.0004963208221813162, 'rewards/margins': 0.24752478301525116, 'rewards/chosen': 0.09160856157541275, 'rewards/rejected': -0.155916228890419, 'logps/margins': 52.59978103637695, 'logps/chosen': -121.93863677978516, 'logps/rejected': -174.5384063720703, 'accuracy': 0.800000011920929, 'epoch': 0.16}
# {'loss': 0.6744, 'learning_rate': 0.0004962386223696459, 'rewards/margins': 0.05652587488293648, 'rewards/chosen': -0.09100936353206635, 'rewards/rejected': -0.14753523468971252, 'logps/margins': -5.46780252456665, 'logps/chosen': -186.02999877929688, 'logps/rejected': -180.56219482421875, 'accuracy': 0.5, 'epoch': 0.17}
# {'loss': 0.6637, 'learning_rate': 0.0004961555213832992, 'rewards/margins': 0.0666571855545044, 'rewards/chosen': 0.1886824071407318, 'rewards/rejected': 0.12202522903680801, 'logps/margins': -8.659854888916016, 'logps/chosen': -156.24383544921875, 'logps/rejected': -147.58399963378906, 'accuracy': 0.6000000238418579, 'epoch': 0.17}
# {'loss': 0.6654, 'learning_rate': 0.000496071519526406, 'rewards/margins': 0.1470455378293991, 'rewards/chosen': -0.027415502816438675, 'rewards/rejected': -0.17446108162403107, 'logps/margins': 24.98568344116211, 'logps/chosen': -143.10787963867188, 'logps/rejected': -168.09356689453125, 'accuracy': 0.699999988079071, 'epoch': 0.17}
# {'loss': 0.7569, 'learning_rate': 0.0004959866171063928, 'rewards/margins': -0.07927528768777847, 'rewards/chosen': -0.06017685681581497, 'rewards/rejected': 0.019098440185189247, 'logps/margins': -6.9485955238342285, 'logps/chosen': -144.28594970703125, 'logps/rejected': -137.3373565673828, 'accuracy': 0.5, 'epoch': 0.17}
# {'loss': 0.6978, 'learning_rate': 0.0004959008144339824, 'rewards/margins': 0.06260564923286438, 'rewards/chosen': 0.18024206161499023, 'rewards/rejected': 0.11763645708560944, 'logps/margins': -28.826190948486328, 'logps/chosen': -176.4118194580078, 'logps/rejected': -147.58560180664062, 'accuracy': 0.5, 'epoch': 0.17}
# {'loss': 0.7549, 'learning_rate': 0.000495814111823192, 'rewards/margins': -0.09869209676980972, 'rewards/chosen': -0.10762326419353485, 'rewards/rejected': -0.008931165561079979, 'logps/margins': -12.85661792755127, 'logps/chosen': -138.5740966796875, 'logps/rejected': -125.71748352050781, 'accuracy': 0.20000000298023224, 'epoch': 0.18}
# {'loss': 0.721, 'learning_rate': 0.0004957265095913327, 'rewards/margins': 0.02253599837422371, 'rewards/chosen': 0.049379922449588776, 'rewards/rejected': 0.02684391476213932, 'logps/margins': -39.495201110839844, 'logps/chosen': -200.62179565429688, 'logps/rejected': -161.12660217285156, 'accuracy': 0.4000000059604645, 'epoch': 0.18}
# {'loss': 0.6028, 'learning_rate': 0.0004956380080590076, 'rewards/margins': 0.28082695603370667, 'rewards/chosen': 0.23085741698741913, 'rewards/rejected': -0.049969516694545746, 'logps/margins': 8.700998306274414, 'logps/chosen': -160.38238525390625, 'logps/rejected': -169.0833740234375, 'accuracy': 0.6000000238418579, 'epoch': 0.18}
# {'loss': 0.5983, 'learning_rate': 0.0004955486075501112, 'rewards/margins': 0.22064633667469025, 'rewards/chosen': 0.026206593960523605, 'rewards/rejected': -0.19443976879119873, 'logps/margins': -14.394346237182617, 'logps/chosen': -168.38525390625, 'logps/rejected': -153.99087524414062, 'accuracy': 0.800000011920929, 'epoch': 0.18}
# {'loss': 0.7066, 'learning_rate': 0.0004954583083918283, 'rewards/margins': 0.04527941346168518, 'rewards/chosen': 0.06982328742742538, 'rewards/rejected': 0.024543877691030502, 'logps/margins': -6.3444504737854, 'logps/chosen': -137.35923767089844, 'logps/rejected': -131.01480102539062, 'accuracy': 0.699999988079071, 'epoch': 0.18}
# {'loss': 0.8735, 'learning_rate': 0.000495367110914632, 'rewards/margins': -0.29001080989837646, 'rewards/chosen': -0.20080192387104034, 'rewards/rejected': 0.08920887112617493, 'logps/margins': 46.33135986328125, 'logps/chosen': -120.70320892333984, 'logps/rejected': -167.03457641601562, 'accuracy': 0.30000001192092896, 'epoch': 0.18}
# {'loss': 0.6461, 'learning_rate': 0.0004952750154522835, 'rewards/margins': 0.16498565673828125, 'rewards/chosen': 0.2820046544075012, 'rewards/rejected': 0.11701901257038116, 'logps/margins': 1.9816806316375732, 'logps/chosen': -137.25704956054688, 'logps/rejected': -139.23873901367188, 'accuracy': 0.6000000238418579, 'epoch': 0.19}
# {'loss': 0.6318, 'learning_rate': 0.0004951820223418303, 'rewards/margins': 0.1869337558746338, 'rewards/chosen': -0.06654921919107437, 'rewards/rejected': -0.25348296761512756, 'logps/margins': -10.969561576843262, 'logps/chosen': -181.00091552734375, 'logps/rejected': -170.03134155273438, 'accuracy': 0.6000000238418579, 'epoch': 0.19}
# {'loss': 0.5887, 'learning_rate': 0.0004950881319236049, 'rewards/margins': 0.2770032286643982, 'rewards/chosen': 0.016443908214569092, 'rewards/rejected': -0.2605593204498291, 'logps/margins': -11.439006805419922, 'logps/chosen': -188.31663513183594, 'logps/rejected': -176.8776397705078, 'accuracy': 0.699999988079071, 'epoch': 0.19}
# {'loss': 0.6538, 'learning_rate': 0.0004949933445412239, 'rewards/margins': 0.2371019572019577, 'rewards/chosen': -0.2634690999984741, 'rewards/rejected': -0.5005711317062378, 'logps/margins': 18.437313079833984, 'logps/chosen': -197.2421112060547, 'logps/rejected': -215.67941284179688, 'accuracy': 0.5, 'epoch': 0.19}
# {'loss': 0.6828, 'learning_rate': 0.0004949072692793723, 'rewards/margins': 0.10970942676067352, 'rewards/chosen': -0.11825238168239594, 'rewards/rejected': -0.22796182334423065, 'logps/margins': -0.650726318359375, 'logps/chosen': -154.5405731201172, 'logps/rejected': -153.88986206054688, 'accuracy': 0.5, 'epoch': 0.19}
# {'loss': 0.7884, 'learning_rate': 0.0004948107786235151, 'rewards/margins': -0.05452927201986313, 'rewards/chosen': -0.2460828274488449, 'rewards/rejected': -0.19155356287956238, 'logps/margins': -34.78037643432617, 'logps/chosen': -197.580810546875, 'logps/rejected': -162.80044555664062, 'accuracy': 0.5, 'epoch': 0.2}
# {'loss': 0.6883, 'learning_rate': 0.0004947133920185493, 'rewards/margins': 0.06694065034389496, 'rewards/chosen': -0.46309694647789, 'rewards/rejected': -0.5300375819206238, 'logps/margins': -6.862048149108887, 'logps/chosen': -159.14974975585938, 'logps/rejected': -152.28768920898438, 'accuracy': 0.6000000238418579, 'epoch': 0.2}
# {'loss': 0.7911, 'learning_rate': 0.0004946151098208867, 'rewards/margins': -0.0983755886554718, 'rewards/chosen': -0.3609727919101715, 'rewards/rejected': -0.2625972032546997, 'logps/margins': 11.172462463378906, 'logps/chosen': -159.6649932861328, 'logps/rejected': -170.8374786376953, 'accuracy': 0.30000001192092896, 'epoch': 0.2}
# {'loss': 0.6945, 'learning_rate': 0.0004945159323902166, 'rewards/margins': 0.030209731310606003, 'rewards/chosen': -0.5074533224105835, 'rewards/rejected': -0.5376630425453186, 'logps/margins': 17.616456985473633, 'logps/chosen': -185.92581176757812, 'logps/rejected': -203.54226684570312, 'accuracy': 0.699999988079071, 'epoch': 0.2}
# {'loss': 0.6739, 'learning_rate': 0.0004944158600895048, 'rewards/margins': 0.09961654245853424, 'rewards/chosen': -0.15256714820861816, 'rewards/rejected': -0.2521836757659912, 'logps/margins': 26.320117950439453, 'logps/chosen': -98.74457550048828, 'logps/rejected': -125.06468200683594, 'accuracy': 0.699999988079071, 'epoch': 0.2}
# {'loss': 0.8871, 'learning_rate': 0.0004943148932849921, 'rewards/margins': -0.19859933853149414, 'rewards/chosen': -0.5048094987869263, 'rewards/rejected': -0.30621013045310974, 'logps/margins': 6.127435207366943, 'logps/chosen': -176.3319549560547, 'logps/rejected': -182.4593963623047, 'accuracy': 0.5, 'epoch': 0.2}
# {'loss': 0.8067, 'learning_rate': 0.0004942130323461931, 'rewards/margins': -0.08831419050693512, 'rewards/chosen': -0.8248531222343445, 'rewards/rejected': -0.7365389466285706, 'logps/margins': 10.054160118103027, 'logps/chosen': -162.25509643554688, 'logps/rejected': -172.30923461914062, 'accuracy': 0.4000000059604645, 'epoch': 0.21}
# {'loss': 0.6124, 'learning_rate': 0.0004941102776458942, 'rewards/margins': 0.20112764835357666, 'rewards/chosen': -0.632593035697937, 'rewards/rejected': -0.8337206840515137, 'logps/margins': 30.968170166015625, 'logps/chosen': -165.82516479492188, 'logps/rejected': -196.79335021972656, 'accuracy': 0.800000011920929, 'epoch': 0.21}
# {'loss': 0.5446, 'learning_rate': 0.0004940066295601534, 'rewards/margins': 0.33926546573638916, 'rewards/chosen': 0.07305443286895752, 'rewards/rejected': -0.26621103286743164, 'logps/margins': -30.765274047851562, 'logps/chosen': -142.60626220703125, 'logps/rejected': -111.84098815917969, 'accuracy': 1.0, 'epoch': 0.21}
# {'loss': 0.7482, 'learning_rate': 0.000493902088468298, 'rewards/margins': -0.07018659263849258, 'rewards/chosen': -0.08153195679187775, 'rewards/rejected': -0.011345356702804565, 'logps/margins': -43.02021026611328, 'logps/chosen': -178.98399353027344, 'logps/rejected': -135.96377563476562, 'accuracy': 0.6000000238418579, 'epoch': 0.21}
# ...
# {'loss': 0.7562, 'learning_rate': 8.142391246911407e-07, 'rewards/margins': 0.5371879935264587, 'rewards/chosen': -5.515676021575928, 'rewards/rejected': -6.0528645515441895, 'logps/margins': 33.4909553527832, 'logps/chosen': -191.62374877929688, 'logps/rejected': -225.1147003173828, 'accuracy': 0.6000000238418579, 'epoch': 2.92}
# {'loss': 1.1344, 'learning_rate': 7.761265575532416e-07, 'rewards/margins': 1.6038990020751953, 'rewards/chosen': -5.904041290283203, 'rewards/rejected': -7.507939338684082, 'logps/margins': 35.50751495361328, 'logps/chosen': -172.6583251953125, 'logps/rejected': -208.1658477783203, 'accuracy': 0.699999988079071, 'epoch': 2.93}
# {'loss': 0.5701, 'learning_rate': 7.389260903993e-07, 'rewards/margins': 2.2284083366394043, 'rewards/chosen': -6.096854209899902, 'rewards/rejected': -8.325262069702148, 'logps/margins': 59.0252799987793, 'logps/chosen': -219.15328979492188, 'logps/rejected': -278.1785888671875, 'accuracy': 0.800000011920929, 'epoch': 2.93}
# {'loss': 0.763, 'learning_rate': 7.026378593741889e-07, 'rewards/margins': 1.414665937423706, 'rewards/chosen': -6.227687358856201, 'rewards/rejected': -7.6423540115356445, 'logps/margins': 73.42909240722656, 'logps/chosen': -186.86767578125, 'logps/rejected': -260.2967834472656, 'accuracy': 0.800000011920929, 'epoch': 2.93}
# {'loss': 1.2328, 'learning_rate': 6.672619972841742e-07, 'rewards/margins': 0.3767862617969513, 'rewards/chosen': -6.561654090881348, 'rewards/rejected': -6.938440799713135, 'logps/margins': -4.5664801597595215, 'logps/chosen': -268.182861328125, 'logps/rejected': -263.61639404296875, 'accuracy': 0.6000000238418579, 'epoch': 2.93}
# {'loss': 1.0974, 'learning_rate': 6.327986335964709e-07, 'rewards/margins': 1.1156980991363525, 'rewards/chosen': -8.294322967529297, 'rewards/rejected': -9.41002082824707, 'logps/margins': 32.26709747314453, 'logps/chosen': -235.2527313232422, 'logps/rejected': -267.51983642578125, 'accuracy': 0.6000000238418579, 'epoch': 2.93}
# {'loss': 0.3192, 'learning_rate': 5.99247894438798e-07, 'rewards/margins': 2.1775100231170654, 'rewards/chosen': -4.288256645202637, 'rewards/rejected': -6.465766906738281, 'logps/margins': 38.691383361816406, 'logps/chosen': -164.18234252929688, 'logps/rejected': -202.87374877929688, 'accuracy': 0.8999999761581421, 'epoch': 2.94}
# {'loss': 0.4366, 'learning_rate': 5.666099025988247e-07, 'rewards/margins': 1.6056864261627197, 'rewards/chosen': -7.0593414306640625, 'rewards/rejected': -8.665027618408203, 'logps/margins': 28.132320404052734, 'logps/chosen': -239.25387573242188, 'logps/rejected': -267.38623046875, 'accuracy': 0.800000011920929, 'epoch': 2.94}
# {'loss': 0.7763, 'learning_rate': 5.348847775238641e-07, 'rewards/margins': 0.3834337294101715, 'rewards/chosen': -6.441342830657959, 'rewards/rejected': -6.824776649475098, 'logps/margins': -12.343162536621094, 'logps/chosen': -272.8724060058594, 'logps/rejected': -260.52923583984375, 'accuracy': 0.6000000238418579, 'epoch': 2.94}
# {'loss': 1.0251, 'learning_rate': 5.040726353202907e-07, 'rewards/margins': 2.4722650051116943, 'rewards/chosen': -7.084298610687256, 'rewards/rejected': -9.556564331054688, 'logps/margins': 55.482574462890625, 'logps/chosen': -229.44570922851562, 'logps/rejected': -284.92828369140625, 'accuracy': 0.800000011920929, 'epoch': 2.94}
# {'loss': 0.6978, 'learning_rate': 4.741735887532073e-07, 'rewards/margins': 1.3971811532974243, 'rewards/chosen': -9.137727737426758, 'rewards/rejected': -10.534910202026367, 'logps/margins': 9.67944622039795, 'logps/chosen': -229.96310424804688, 'logps/rejected': -239.64254760742188, 'accuracy': 0.6000000238418579, 'epoch': 2.94}
# {'loss': 0.4691, 'learning_rate': 4.451877472460009e-07, 'rewards/margins': 1.1178499460220337, 'rewards/chosen': -3.842463731765747, 'rewards/rejected': -4.960313320159912, 'logps/margins': 24.155763626098633, 'logps/chosen': -160.42848205566406, 'logps/rejected': -184.58424377441406, 'accuracy': 0.800000011920929, 'epoch': 2.94}
# {'loss': 0.6984, 'learning_rate': 4.171152168799264e-07, 'rewards/margins': 1.8203647136688232, 'rewards/chosen': -5.770889759063721, 'rewards/rejected': -7.591254234313965, 'logps/margins': 3.168374538421631, 'logps/chosen': -227.3218994140625, 'logps/rejected': -230.49026489257812, 'accuracy': 0.800000011920929, 'epoch': 2.95}
# {'loss': 0.4947, 'learning_rate': 3.8995610039380125e-07, 'rewards/margins': 2.5874428749084473, 'rewards/chosen': -4.975779056549072, 'rewards/rejected': -7.5632219314575195, 'logps/margins': 23.45920753479004, 'logps/chosen': -174.17251586914062, 'logps/rejected': -197.63174438476562, 'accuracy': 0.800000011920929, 'epoch': 2.95}
# {'loss': 0.6397, 'learning_rate': 3.6371049718347816e-07, 'rewards/margins': 1.2635360956192017, 'rewards/chosen': -4.364542484283447, 'rewards/rejected': -5.628078460693359, 'logps/margins': -4.229788303375244, 'logps/chosen': -210.0941619873047, 'logps/rejected': -205.8643798828125, 'accuracy': 0.5, 'epoch': 2.95}
# {'loss': 0.5562, 'learning_rate': 3.383785033016229e-07, 'rewards/margins': 2.9683032035827637, 'rewards/chosen': -3.745420455932617, 'rewards/rejected': -6.713723659515381, 'logps/margins': 32.45201110839844, 'logps/chosen': -208.2792510986328, 'logps/rejected': -240.7312469482422, 'accuracy': 0.8999999761581421, 'epoch': 2.95}
# {'loss': 2.3008, 'learning_rate': 3.139602114572704e-07, 'rewards/margins': 0.14104481041431427, 'rewards/chosen': -7.866971492767334, 'rewards/rejected': -8.008016586303711, 'logps/margins': -3.131488800048828, 'logps/chosen': -221.3490753173828, 'logps/rejected': -218.2175750732422, 'accuracy': 0.6000000238418579, 'epoch': 2.95}
# {'loss': 0.9106, 'learning_rate': 2.9045571101560253e-07, 'rewards/margins': 1.6638292074203491, 'rewards/chosen': -5.509058952331543, 'rewards/rejected': -7.172888278961182, 'logps/margins': -11.281573295593262, 'logps/chosen': -232.78170776367188, 'logps/rejected': -221.5001220703125, 'accuracy': 0.6000000238418579, 'epoch': 2.96}
# {'loss': 0.6742, 'learning_rate': 2.678650879974764e-07, 'rewards/margins': 2.6065917015075684, 'rewards/chosen': -5.122988224029541, 'rewards/rejected': -7.729579925537109, 'logps/margins': 61.22240447998047, 'logps/chosen': -199.11172485351562, 'logps/rejected': -260.3341369628906, 'accuracy': 0.699999988079071, 'epoch': 2.96}
# {'loss': 0.8879, 'learning_rate': 2.461884250791468e-07, 'rewards/margins': 0.21348552405834198, 'rewards/chosen': -8.025782585144043, 'rewards/rejected': -8.239267349243164, 'logps/margins': -34.957374572753906, 'logps/chosen': -245.3704376220703, 'logps/rejected': -210.41305541992188, 'accuracy': 0.4000000059604645, 'epoch': 2.96}
# {'loss': 0.2352, 'learning_rate': 2.254258015920718e-07, 'rewards/margins': 3.573995590209961, 'rewards/chosen': -6.210386753082275, 'rewards/rejected': -9.784382820129395, 'logps/margins': 106.05252838134766, 'logps/chosen': -187.30368041992188, 'logps/rejected': -293.356201171875, 'accuracy': 0.8999999761581421, 'epoch': 2.96}
# {'loss': 1.0523, 'learning_rate': 2.0557729352249642e-07, 'rewards/margins': 1.805855393409729, 'rewards/chosen': -6.633350372314453, 'rewards/rejected': -8.439205169677734, 'logps/margins': 15.847012519836426, 'logps/chosen': -235.29525756835938, 'logps/rejected': -251.14230346679688, 'accuracy': 0.800000011920929, 'epoch': 2.96}
# {'loss': 0.6214, 'learning_rate': 1.8664297351120296e-07, 'rewards/margins': 0.9713283777236938, 'rewards/chosen': -4.501400470733643, 'rewards/rejected': -5.472728252410889, 'logps/margins': 36.737022399902344, 'logps/chosen': -182.68637084960938, 'logps/rejected': -219.4233856201172, 'accuracy': 0.6000000238418579, 'epoch': 2.96}
# {'loss': 0.5706, 'learning_rate': 1.6862291085334435e-07, 'rewards/margins': 3.6481449604034424, 'rewards/chosen': -6.04340124130249, 'rewards/rejected': -9.691545486450195, 'logps/margins': 32.122310638427734, 'logps/chosen': -236.91610717773438, 'logps/rejected': -269.0384216308594, 'accuracy': 0.800000011920929, 'epoch': 2.97}
# {'loss': 0.5345, 'learning_rate': 1.515171714980279e-07, 'rewards/margins': 2.096212863922119, 'rewards/chosen': -4.50253438949585, 'rewards/rejected': -6.598747253417969, 'logps/margins': 33.049686431884766, 'logps/chosen': -187.20266723632812, 'logps/rejected': -220.25234985351562, 'accuracy': 0.6000000238418579, 'epoch': 2.97}
# {'loss': 0.778, 'learning_rate': 1.3532581804817646e-07, 'rewards/margins': 0.7831788063049316, 'rewards/chosen': -4.207425117492676, 'rewards/rejected': -4.990604400634766, 'logps/margins': 6.939971923828125, 'logps/chosen': -191.44052124023438, 'logps/rejected': -198.38050842285156, 'accuracy': 0.699999988079071, 'epoch': 2.97}
# {'loss': 0.5103, 'learning_rate': 1.200489097602786e-07, 'rewards/margins': 2.7910475730895996, 'rewards/chosen': -6.7807464599609375, 'rewards/rejected': -9.571794509887695, 'logps/margins': 56.30474853515625, 'logps/chosen': -239.1135711669922, 'logps/rejected': -295.4183044433594, 'accuracy': 0.699999988079071, 'epoch': 2.97}
# {'loss': 0.6897, 'learning_rate': 1.0568650254419443e-07, 'rewards/margins': 0.5463464856147766, 'rewards/chosen': -5.427749156951904, 'rewards/rejected': -5.974095344543457, 'logps/margins': -5.3647356033325195, 'logps/chosen': -221.54385375976562, 'logps/rejected': -216.1791534423828, 'accuracy': 0.699999988079071, 'epoch': 2.97}
# {'loss': 0.9397, 'learning_rate': 9.223864896293343e-08, 'rewards/margins': -0.13300976157188416, 'rewards/chosen': -3.7095279693603516, 'rewards/rejected': -3.5765178203582764, 'logps/margins': -16.49566078186035, 'logps/chosen': -179.4760284423828, 'logps/rejected': -162.9803466796875, 'accuracy': 0.4000000059604645, 'epoch': 2.98}
# {'loss': 0.3166, 'learning_rate': 7.970539823237699e-08, 'rewards/margins': 1.9792706966400146, 'rewards/chosen': -7.507953643798828, 'rewards/rejected': -9.487225532531738, 'logps/margins': -16.420455932617188, 'logps/chosen': -269.710693359375, 'logps/rejected': -253.2902069091797, 'accuracy': 0.8999999761581421, 'epoch': 2.98}
# {'loss': 0.1348, 'learning_rate': 6.808679622127834e-08, 'rewards/margins': 3.3183884620666504, 'rewards/chosen': -4.855159282684326, 'rewards/rejected': -8.173547744750977, 'logps/margins': 66.62206268310547, 'logps/chosen': -184.19171142578125, 'logps/rejected': -250.81375122070312, 'accuracy': 1.0, 'epoch': 2.98}
# {'loss': 1.1268, 'learning_rate': 5.738288545095727e-08, 'rewards/margins': 1.3159475326538086, 'rewards/chosen': -5.371336460113525, 'rewards/rejected': -6.687283992767334, 'logps/margins': 7.097840785980225, 'logps/chosen': -237.1343536376953, 'logps/rejected': -244.232177734375, 'accuracy': 0.699999988079071, 'epoch': 2.98}
# {'loss': 0.7193, 'learning_rate': 4.759370509513361e-08, 'rewards/margins': 2.986098527908325, 'rewards/chosen': -5.958545207977295, 'rewards/rejected': -8.944644927978516, 'logps/margins': 3.1214935779571533, 'logps/chosen': -244.1617431640625, 'logps/rejected': -247.28323364257812, 'accuracy': 0.800000011920929, 'epoch': 2.98}
# {'loss': 0.4216, 'learning_rate': 3.871929097992721e-08, 'rewards/margins': 1.375125765800476, 'rewards/chosen': -6.4170823097229, 'rewards/rejected': -7.792208671569824, 'logps/margins': 14.549463272094727, 'logps/chosen': -218.89584350585938, 'logps/rejected': -233.44534301757812, 'accuracy': 0.800000011920929, 'epoch': 2.99}
# {'loss': 0.4982, 'learning_rate': 3.075967558355264e-08, 'rewards/margins': 1.9523025751113892, 'rewards/chosen': -4.4885663986206055, 'rewards/rejected': -6.440868377685547, 'logps/margins': 1.626673936843872, 'logps/chosen': -167.1802215576172, 'logps/rejected': -168.80691528320312, 'accuracy': 0.6000000238418579, 'epoch': 2.99}
# {'loss': 0.0957, 'learning_rate': 2.3714888036291403e-08, 'rewards/margins': 3.908054828643799, 'rewards/chosen': -4.984347820281982, 'rewards/rejected': -8.892402648925781, 'logps/margins': 34.748695373535156, 'logps/chosen': -174.36782836914062, 'logps/rejected': -209.1165008544922, 'accuracy': 1.0, 'epoch': 2.99}
# {'loss': 0.788, 'learning_rate': 1.7584954120408725e-08, 'rewards/margins': 1.7885637283325195, 'rewards/chosen': -6.870445251464844, 'rewards/rejected': -8.659008979797363, 'logps/margins': 93.69609069824219, 'logps/chosen': -183.7585906982422, 'logps/rejected': -277.45465087890625, 'accuracy': 0.6000000238418579, 'epoch': 2.99}
# {'loss': 0.4345, 'learning_rate': 1.2369896269986968e-08, 'rewards/margins': 1.0755952596664429, 'rewards/chosen': -6.264309883117676, 'rewards/rejected': -7.33990478515625, 'logps/margins': 56.860130310058594, 'logps/chosen': -199.2567901611328, 'logps/rejected': -256.11688232421875, 'accuracy': 0.800000011920929, 'epoch': 2.99}
# {'loss': 1.6973, 'learning_rate': 8.069733570925663e-09, 'rewards/margins': -0.504814863204956, 'rewards/chosen': -7.594829559326172, 'rewards/rejected': -7.090015411376953, 'logps/margins': 36.34052658081055, 'logps/chosen': -221.83450317382812, 'logps/rejected': -258.17498779296875, 'accuracy': 0.4000000059604645, 'epoch': 2.99}
# {'loss': 0.5034, 'learning_rate': 4.684481760747206e-09, 'rewards/margins': 1.258862853050232, 'rewards/chosen': -3.1787259578704834, 'rewards/rejected': -4.437588691711426, 'logps/margins': -21.1375675201416, 'logps/chosen': -223.5233917236328, 'logps/rejected': -202.3857879638672, 'accuracy': 0.6000000238418579, 'epoch': 3.0}
# {'loss': 0.3659, 'learning_rate': 2.2141532287078826e-09, 'rewards/margins': 2.3313162326812744, 'rewards/chosen': -5.35056734085083, 'rewards/rejected': -7.681883335113525, 'logps/margins': -24.266748428344727, 'logps/chosen': -195.14950561523438, 'logps/rejected': -170.88278198242188, 'accuracy': 0.699999988079071, 'epoch': 3.0}
# {'loss': 0.4991, 'learning_rate': 6.587570156035838e-10, 'rewards/margins': 1.3954836130142212, 'rewards/chosen': -4.205542087554932, 'rewards/rejected': -5.601025581359863, 'logps/margins': 1.134281873703003, 'logps/chosen': -201.49404907226562, 'logps/rejected': -202.6283416748047, 'accuracy': 0.800000011920929, 'epoch': 3.0}
# 100% 16422/16422 [14:06<00:00, 21.68it/s]/usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:198: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   adapters_weights = torch.load(filename, map_location=torch.device(device))
# {'train_runtime': 846.0612, 'train_samples_per_second': 19.41, 'train_steps_per_second': 19.41, 'train_loss': 0.7533114446442102, 'epoch': 3.0}
# 100% 16422/16422 [14:06<00:00, 19.41it/s]
# [rank0]:[W1015 11:07:56.217069485 ProcessGroupNCCL.cpp:1168] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())
